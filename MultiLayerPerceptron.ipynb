# %% [markdown]
# <a href="https://colab.research.google.com/github/deep19x/Deep-Learning/blob/main/MultiLayerPerceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
import tensorflow as tf

# %%
import numpy as np
T = 1.0
F = 0.0

def get_XOR_data():
  X = [
      [F,F],
      [F,T],
      [T,F],
      [T,T]
  ]

  Y = [
      [F],
      [T],
      [T],
      [F]
  ]
  return X,Y

# %%
X,Y = get_XOR_data()
X_test = [
    [T,F],
    [T,T],
    [F,T],
    [F,F]
]

Y_test = [
    [T],
    [F],
    [T],
    [F]
]

# %%
X = np.array(X, dtype=float)
Y = np.array(Y, dtype=float)

X_test = np.array(X_test, dtype=float)
Y_test = np.array(Y_test, dtype=float)

# %%
model = Sequential()
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',optimizer='SGD',metrics=['accuracy'])

# %%
model.fit(X,Y,epochs=100)
loss,accuracy = model.evaluate(X_test,Y_test,verbose=0)
print('Accuracy : %.2f' % (accuracy*100))
print(loss)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 783ms/step - accuracy: 0.5000 - loss: 0.7219
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5000 - loss: 0.7218
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5000 - loss: 0.7217
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5000 - loss: 0.7216
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.5000 - loss: 0.7215
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5000 - loss: 0.7214
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 0.7213
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.7212
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 0.7211
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.7210
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.7209
# Epoch 12/100
# ...
