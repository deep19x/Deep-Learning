# %% [markdown]
# <a href="https://colab.research.google.com/github/deep19x/Deep-Learning/blob/main/Implementation_of_Single_Layer_Perceptron_(Logistic_Regression)_for_Glass_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('/content/glass.csv')
print(data.shape)
print(data.head())
# Out:
# (214, 10)
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
if "Id" in data.columns:
  data = data.drop('id',axis=1)

# %%
X = data.drop('Type',axis=1)
Y = data['Type']

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
Y = encoder.fit_transform(Y)   # Converts to 0,1,2,3,4,5

Y = to_categorical(Y)

X_train,X_test,Y_train,Y_test = train_test_split(
    X,Y,
    test_size=0.2,
    random_state=42
)

# %%
scalar = StandardScaler()

X_train = scalar.fit_transform(X_train)
X_test = scalar.transform(X_test)

# %%
model = Sequential()

model.add(Dense(
    units=Y.shape[1],
    input_shape=(X.shape[1],),
    activation="softmax"
))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(
    X_train,
    Y_train,
    epochs=100,
    batch_size=8,
    validation_split=0.1
)


loss, accuracy = model.evaluate(X_test, Y_test)

print("\nTest Accuracy:", accuracy*100)
print("Test Loss:", loss)


pred = model.predict(X_test[:5])

print("\nPredicted:", np.argmax(pred, axis=1))
print("Actual   :", np.argmax(Y_test[:5], axis=1))
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.1162 - loss: 2.3358 - val_accuracy: 0.1111 - val_loss: 2.2920
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1552 - loss: 2.2279 - val_accuracy: 0.1111 - val_loss: 2.2459
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2334 - loss: 2.1616 - val_accuracy: 0.1667 - val_loss: 2.1958
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2683 - loss: 1.9315 - val_accuracy: 0.1667 - val_loss: 2.1576
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2793 - loss: 1.9902 - val_accuracy: 0.1667 - val_loss: 2.1146
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2856 - loss: 1.9668 - val_accuracy: 0.2778 - val_loss: 2.0748
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2595 - loss: 2.0038 - val_accuracy: 0.2222 - val_loss: 2.0305
# Epoch 8/100
# ...
